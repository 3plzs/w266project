# %%
import os
import pandas as pd
import numpy as np

# %%
os.listdir()
# Out:
# ['Coversations_Filtered.xlsx',
#  'Conversations_Filtered_Steven.xlsx',
#  '.DS_Store',
#  'Untitled.ipynb',
#  'Coversations_Filtered_Full.xlsx',
#  'responses',
#  'Tweet Tagger with loop to pull conversations.ipynb',
#  'Conversations_Filtered_FIlippos.xlsx',
#  'Tweet Tagger with loop to pull conversations.ipynb.zip',
#  '.ipynb_checkpoints',
#  'Coversations_Unfiltered.xlsx']

# %%
data = pd.read_excel('Conversations_Filtered_Steven.xlsx',sheet_name="Sheet1")

# %%
data[data["Personal Attack?"]==1]
# Out:
#      Tweet ID      Conversation ID  Depth         Username  \
# 29       2027  1181675228004585472      3     TreybaileCEO
# 70       2068  1084957243420753922      4       SinaiGail9
# 98       2096  1106330130329362434      5   jesseharris345
# 143      2141  1148355869182234624      4  CindyGordonSKCR
# 152      2150  1157413739861356545      3   nahalidabarbie
# 170      2168  1175168640771088384      2    versa_styling
# 171      2169  1175168640771088384      3         HolesMad
# 173      2171  1175168640771088384      5       Capt_MikeM
# 213      2211  1208478312651280385      3    alebiosu_razi
# 297      2295  1149370058226847744      7            eshap
# 298      2296  1149370058226847744      8  Peaches_Sabrina
# 302      2300  1149370058226847744     12            eshap
# 303      2301  1149370058226847744     13  Peaches_Sabrina
# 304      2302  1149370058226847744     14            eshap
# 305      2303  1149370058226847744     15  Peaches_Sabrina
# ...

# %%
data[data["Conversation ID"]==1149370058226847744	]
# Out:
#      Tweet ID      Conversation ID  Depth         Username  \
# 291      2289  1149370058226847744      1            eshap
# 292      2290  1149370058226847744      2  Peaches_Sabrina
# 293      2291  1149370058226847744      3     FrancaRose33
# 294      2292  1149370058226847744      4  Peaches_Sabrina
# 295      2293  1149370058226847744      5            eshap
# 296      2294  1149370058226847744      6  Peaches_Sabrina
# 297      2295  1149370058226847744      7            eshap
# 298      2296  1149370058226847744      8  Peaches_Sabrina
# 299      2297  1149370058226847744      9     FrancaRose33
# 300      2298  1149370058226847744     10  Peaches_Sabrina
# 301      2299  1149370058226847744     11     FrancaRose33
# 302      2300  1149370058226847744     12            eshap
# 303      2301  1149370058226847744     13  Peaches_Sabrina
# 304      2302  1149370058226847744     14            eshap
# 305      2303  1149370058226847744     15  Peaches_Sabrina
# ...

# %%
data_fi = pd.read_excel("Conversations_Filtered_FIlippos.xlsx")

# %%
data_fi
# Out:
#       Tweet ID      Conversation ID  Depth         Username  \
# 0            1  1212519416723836928      1   TheMarkPantano
# 1            2  1212519416723836928      2   TheMarkPantano
# 2            3  1212519416723836928      3         Etherkat
# 3            4  1217958873232863232      1     AmandaPerram
# 4            5  1217958873232863232      2   HenriMcAlister
# ...        ...                  ...    ...              ...
# 1992      1993  1152717176643760136      2        Miss_Vexx
# 1993      1994  1152717176643760136      3  Kittycatsnuggle
# 1994      1995  1158508788447612929      1  animalrights_JP
# 1995      1996  1158508788447612929      2       ibu_96neko
# 1996      1997  1158508788447612929      3       ibu_96neko
#
#                                                   Tweet                 Date
# 0     Enjoy the Trump Presidency while it lasts.  Du...  2020-01-01 18:42:11
# 1     @Etherkat By the way, I see that you pretend t...  2020-01-02 12:34:22
# ...

# %%
data_fi[data_fi["Personal Attack?"]==1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Personal Attack?'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-35036d4f1378> in <module>
# ...
